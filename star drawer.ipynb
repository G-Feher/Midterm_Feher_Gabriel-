# %%
import turtle
t = turtle.Turtle()

#drawing the star

length = 200 

t.left(36)
t.forward(length)
t.left(144)
t.forward(length)
t.left(144)
t.forward(length)
t.left(144)
t.forward(length)
t.left(144)
t.forward(length)

# %%
import turtle
t = turtle.Turtle()

t.pendown
t.left(36)
def star(length):
    for i in range(5):
        t.forward(length)
        t.left(144)
t.penup
star(300)

# %%
import turtle
t = turtle.Turtle()
t.speed(0)

length=100
t.left(36)
def star(length):
    t.pendown()
    for i in range(5):
        t.forward(length)
        t.left(144)
t.penup

y=0
x=-100
t.penup()
for i in range(6):
    t.setpos(x,y)
    star(100)
x += 200
y = 0

# %%
import turtle
t = turtle.Turtle()
t.speed(0)
t.left(36)

def five_star(length):
    t.pendown()
    for i in range (5):
        t.forward(length)
        t.left(144)
    t.penup
    
x_position = - 100
def six_row():
    t.penup()
    for i in range (6):
        global x_position
        t.setpos(x_position,0)
        five_star(25)
        x_position += 50
        t.penup()
        
six_row()
# Out:
#   File "<ipython-input-2-c0613c55a24e>", line 26
#     six_row()
#     ^
# IndentationError: expected an indented block

# %%
import turtle
t = turtle.Turtle()
t.speed(0)
t.left(36)
t.penup()

length = 50
def five_star(length):
    t.pendown()
    for i in range (5):
        t.forward(length)
        t.left(144)
    t.penup
    
x_position = - 100
y_position = 100
#drawing 1 row
def star_row(n):
    t.penup()
    for i in range (n):
        global x_position
        global y_position
        t.setpos(x_position,y_position)
        five_star(25)
        x_position += 50
        t.penup()
#row drawer
for i in range (5):
    star_row(6)
    x_position = -100
    y_position -= 50
    
x_position = -75
y_position = 75
for i in range (4):
    star_row(5)
    x_position = -75
    y_position -= 50

# %%
import turtle
t = turtle.Turtle()
t.speed(0)
t.left(36)
t.penup()

#blue rectangle
t.color('blue')
t.begin_fill()
t.setpos(-115,135)
t.setpos(180,135)
t.setpos(180,-115)
t.setpos(-115,-115)
t.setpos(-115,135)
t.end_fill()


#star drawer
length = 50
def five_star(length):
    t.pendown()
    t.color('white')
    t.begin_fill()
    for i in range (5):
        t.forward(length)
        t.left(144)
    t.end_fill()
    t.penup
    
#drawing 1 row
x_position = - 100
y_position = 100
def star_row(n):
    t.penup()
    for i in range (n):
        global x_position
        global y_position
        t.setpos(x_position,y_position)
        five_star(25)
        x_position += 50
        t.penup()
        
#row drawer
for i in range (5):
    star_row(6)
    x_position = -100
    y_position -= 50
    
x_position = -75
y_position = 75
for i in range (4):
    star_row(5)
    x_position = -75
    y_position -= 50

# %%
import turtle
t = turtle.Turtle()
t.speed(0)
t.left(36)
t.penup()

#blue rectangle
t.color('blue')
t.begin_fill()
t.setpos(-115,135)
t.setpos(180,135)
t.setpos(180,-115)
t.setpos(-115,-115)
t.setpos(-115,135)
t.end_fill()


#star drawer
length = 50
color = ['red','white','blue']
def draw_star(length,color):
    t.pendown()
    t.color('color')
    t.begin_fill()
    for i in range (5):
        t.forward(length)
        t.left(144)
    t.end_fill()
    t.penup
    
#drawing 1 row
x_position = - 100
y_position = 100
def star_row(n):
    t.penup()
    for i in range (n):
        global x_position
        global y_position
        t.setpos(x_position,y_position)
        draw_star(25)
        x_position += 50
        t.penup()
        
#row drawer
for i in range (5):
    star_row(6)
    x_position = -100
    y_position -= 50
    
x_position = -75
y_position = 75
for i in range (4):
    star_row(5)
    x_position = -75
    y_position -= 50

# %%
import turtle
t = turtle.Turtle()
t.speed(0)
t.left(36)
t.penup()

#star drawer
color = ['red','white','blue']
def draw_star(float,color):
    t.pendown()
    t.color(color)
    t.begin_fill()
    for i in range (5):
        t.forward(float)
        t.left(144)
    t.end_fill()
    t.penup

draw_star(110.20,'red')
